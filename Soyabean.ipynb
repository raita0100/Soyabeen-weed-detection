# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/220.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/151.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/229.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1168.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/842.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1133.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/822.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/425.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/714.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/63.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/783.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/205.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/413.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/608.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/458.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/987.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/137.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/285.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1062.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/860.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/871.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/643.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/231.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/249.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/907.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/162.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1093.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1065.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/491.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/48.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/612.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/525.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/845.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/360.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/391.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1066.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/174.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/885.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/813.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/603.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1127.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/320.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/513.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/742.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/141.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/224.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1152.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1115.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/633.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/170.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/267.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1177.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/142.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/622.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/904.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/153.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/827.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/427.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1130.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/933.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1176.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/560.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/57.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/30.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1017.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/321.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/855.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/934.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/123.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/24.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/544.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/156.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/988.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/713.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/682.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/116.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/399.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1081.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1035.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1120.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1186.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/754.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/448.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/452.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/35.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1167.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/676.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/59.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/155.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/543.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/667.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/22.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/782.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/45.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/369.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1103.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/334.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/375.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/480.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1013.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/833.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/992.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/444.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/106.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/834.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1105.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/961.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1052.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/652.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1004.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/462.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/661.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/79.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/639.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/209.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/926.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/218.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/418.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/798.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/160.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/237.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1149.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/881.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/824.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/215.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/144.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/472.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/589.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/943.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/781.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/591.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/21.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/780.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/941.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1009.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/241.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1086.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/528.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/14.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1144.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/323.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1134.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1064.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/814.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/736.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/978.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1073.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/545.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/944.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/596.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1031.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1008.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1020.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/313.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/481.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/538.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/738.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1101.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/514.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/659.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/631.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1106.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1107.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/888.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1182.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/423.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/336.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/810.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1178.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/117.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1007.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/576.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/281.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/711.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1030.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/680.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/168.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/353.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/202.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/395.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/36.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/684.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/769.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/552.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/252.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/145.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/995.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1022.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/900.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/634.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/637.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1117.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/445.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/701.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/435.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/478.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1138.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/737.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/618.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/193.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/316.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1158.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1039.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/322.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/470.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/169.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/489.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/58.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/797.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/601.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/640.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/550.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/687.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/853.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/120.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/307.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1080.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/200.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/982.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1098.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/815.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/337.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1015.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/728.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/609.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1025.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/962.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/594.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/140.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/778.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/464.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/244.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/112.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/62.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/290.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/734.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/111.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/623.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1154.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/431.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/748.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/199.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/632.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1003.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/264.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/570.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/777.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/398.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/195.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/176.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/284.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/727.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/984.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/584.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/581.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/939.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/67.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1091.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/258.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1125.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/790.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1044.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/971.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/443.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/527.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/803.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/880.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/529.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/165.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/71.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/768.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/115.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1114.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/715.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/959.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/10.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/303.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/196.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/990.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/664.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/94.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/620.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/335.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/319.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/889.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/796.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/471.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/484.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/306.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/188.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/343.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/409.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/966.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/157.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/192.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/87.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/288.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/455.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/354.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1189.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/744.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/863.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/548.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/656.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/980.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/406.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/918.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/400.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/265.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/302.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/466.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1135.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1180.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/677.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/894.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/198.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/405.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/118.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/621.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/916.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/97.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/709.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/674.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/479.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/226.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/911.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/41.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/349.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/645.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/311.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/255.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/983.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/951.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1010.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/178.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/997.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/108.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1116.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1024.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/607.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1096.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/986.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/72.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1005.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/390.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/938.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/440.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/862.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/352.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/605.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/568.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/89.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/324.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/663.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/920.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1163.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/963.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/578.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/86.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1006.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/92.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/508.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/644.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1082.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/651.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/404.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/763.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/878.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/5.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/126.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1160.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/689.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/190.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1191.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/261.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1159.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/438.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1085.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/516.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1047.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/950.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1151.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/564.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/932.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/506.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/28.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/29.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1112.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/524.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1094.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/956.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/703.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/626.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/657.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/914.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/206.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/248.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1063.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1054.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1145.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/952.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/412.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/460.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/233.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/104.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/175.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/732.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/163.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/922.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/912.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/915.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/219.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/772.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/856.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/383.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/775.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/434.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/389.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/994.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/590.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/459.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/641.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/858.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/84.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1122.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/794.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1016.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/540.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/854.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/359.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/181.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/50.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/328.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/65.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/802.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/279.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/864.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1067.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/4.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/870.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/567.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/263.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1021.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/800.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/908.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/942.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/105.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/236.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/892.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/835.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/921.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/410.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/420.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/83.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/906.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/204.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/579.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/566.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/521.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/831.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/368.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1023.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/849.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/679.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/433.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/135.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/886.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/235.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1076.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/668.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/486.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/733.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/844.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/791.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/396.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/136.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1136.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/765.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/582.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/361.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1036.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/182.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/836.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1110.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/893.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/746.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/201.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/211.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1002.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/872.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/828.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/250.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/574.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/559.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1188.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1042.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/638.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/937.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/531.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/879.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/310.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/614.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/88.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/269.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/131.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/577.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/503.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/848.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/102.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/430.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/771.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/897.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1050.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/110.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/565.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/501.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1037.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/859.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/254.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/873.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/230.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/779.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1175.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/262.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1141.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/318.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/534.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/485.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/795.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/393.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/330.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/887.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/428.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/597.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/98.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/766.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/421.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/101.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/825.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/747.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/299.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/761.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/712.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/362.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/706.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/283.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/366.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1032.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/557.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/913.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/317.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/555.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/242.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/95.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/339.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/793.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/373.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/549.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/103.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/47.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/647.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/239.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/587.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/15.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/708.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/955.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/17.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/243.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/551.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/968.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/12.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/463.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1014.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/93.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/868.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/454.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/424.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/598.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/365.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/799.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/627.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/752.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/340.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/245.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/692.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/119.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/764.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/475.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/37.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/610.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/147.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/133.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1165.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/976.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/291.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1171.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/837.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/967.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/46.tif
# ...
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4008.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4917.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2312.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4600.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2966.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5868.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1494.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4496.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1337.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4483.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1876.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7367.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3237.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3014.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4906.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6368.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6188.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5282.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2303.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4207.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3245.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3300.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5007.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6387.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6357.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/998.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6054.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2001.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5985.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/259.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6241.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2432.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/707.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6136.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7308.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5739.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2295.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1230.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3622.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3776.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/743.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4334.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/929.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7032.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6809.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1095.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/356.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1904.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1797.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1777.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4697.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1967.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6590.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7255.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2932.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1919.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4539.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2739.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4195.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4038.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3396.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2667.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4050.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2480.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5365.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4431.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4754.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2771.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7230.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6813.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5689.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5592.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4841.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5664.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7272.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3772.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1508.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6232.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3145.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4325.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1727.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7223.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3798.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4041.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3224.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3443.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1124.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3096.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1486.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6812.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1146.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6789.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6492.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2628.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1856.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6566.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2730.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6019.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1211.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5262.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6867.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6931.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1068.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3598.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/806.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1040.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6999.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7144.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6229.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3659.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3698.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6318.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6705.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4898.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5721.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6556.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4361.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1012.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7161.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5071.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4551.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1825.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1166.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1236.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2610.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/954.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5280.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6045.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3730.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1284.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3817.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2531.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2525.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7129.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1972.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6575.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5544.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/411.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7227.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4034.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3239.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3504.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3100.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7251.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5548.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3140.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4683.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6444.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5908.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6155.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7119.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6087.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5167.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4603.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2784.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1019.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1137.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4356.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2548.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/457.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5811.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3996.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7327.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3819.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2563.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5638.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6848.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3071.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2780.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7023.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5871.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6538.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/394.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2206.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2296.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/653.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4185.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5766.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6266.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4317.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6606.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4106.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6341.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3596.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4281.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/3464.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6937.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7363.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/683.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7283.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1249.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/7298.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2441.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/4739.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/2497.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6409.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6441.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1139.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/5666.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/6084.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/soybean/1058.tif

# %%
import matplotlib.pyplot as plt
import cv2
import glob

# %%
data_dir = r'/kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/' # Setting the dataset directory
classes = ['broadleaf', 'grass', 'soil', 'soybean'] # Setting all the available classes

num_file = 1100 # Number of files
all_files = []
num_data = num_file * len(classes)
Y = np.zeros(num_data) # Initialize all output values with 0

# Get the files
for i, cls in enumerate(classes):
  all_files += [f for f in glob.glob(data_dir + cls + '/*.tif')][:num_file]
  Y[i * num_file: (i + 1) * num_file] = i # Label all classes with int [0.. len(classes)]

image_width = 200
image_height = 200
image_channel = 3
dimension = image_width * image_height * image_channel

X = np.ndarray(shape=(num_data, image_width, image_height, image_channel), dtype=np.uint8) # Create a nd array

for i, file in enumerate(all_files):
  X[i] = cv2.resize(cv2.imread(file), (image_width, image_height)) # Add and load all images

# Split training, validation and testing set by creating empty arrays
X_train = np.empty(shape=(4000, image_width, image_height, image_channel), dtype=np.uint8)
X_val = np.empty(shape=(200, image_width, image_height, image_channel), dtype=np.uint8)
X_test = np.empty(shape=(200, image_width, image_height, image_channel), dtype=np.uint8)

Y_train = np.empty(4000)
Y_val = np.empty(200)
Y_test = np.empty(200)

# Set all x and y values
for i, cls in enumerate(classes):
  X_test[50 * i: 50 * (i + 1)] = X[np.where(Y == i)[0][:50]]
  X_val[50 * i: 50 * (i + 1)] = X[np.where(Y == i)[0][50:100]]
  X_train[1000 * i: 1000 * (i + 1)] = X[np.where(Y == i)[0][100:]]

  Y_test[50 * i: 50 * (i + 1)] = i
  Y_val[50 * i: 50 * (i + 1)] = i
  Y_train[1000 * i: 1000 * (i + 1)] = i

# Save some memory by deleting X and Y
del Y
del X

# Select random x and y train data
train_indexes = np.random.permutation(X_train.shape[0]) # Create random indexes array with the length of X_train.shape[0]
Y_train = Y_train[train_indexes].astype(int) 
X_train = X_train[train_indexes]

# Reshape the train, test, val data
X_train = np.reshape(X_train, (X_train.shape[0], -1)).astype('float64')
X_test = np.reshape(X_test, (X_test.shape[0], -1)).astype('float64')
X_val = np.reshape(X_val, (X_val.shape[0], -1)).astype('float64')

# Create custom tiny dataset for testing
X_tiny = X_train[100:110].astype('float64')
Y_tiny = Y_train[100:110].astype(int)
num_dev = 500

# Create custom dev dataset for testing
X_dev = X_train[0:num_dev].astype('float64')
Y_dev = Y_train[0:num_dev].astype(int)

# Compute the mean image
mean_image = np.mean(X_train, axis=0) # axis=0. stack horizontally
# Subtract the mean image from train and test data 
X_train -= mean_image
X_val -= mean_image 
X_test -= mean_image
X_dev -= mean_image
X_tiny -= mean_image

print("X_train shape", X_train.shape)
print("X_test shape", X_test.shape)
print("X_val shape", X_val.shape)
print("X_dev shape", X_dev.shape)
print("X_tiny shape", X_tiny.shape)
# Out:
# X_train shape (4000, 120000)
# X_test shape (200, 120000)
# X_val shape (200, 120000)
# X_dev shape (500, 120000)
# X_tiny shape (10, 120000)

# %%
plt.rcParams['figure.figsize'] = (12.0, 8.0)
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %%
classes = ['broadleaf', 'grass', 'soil', 'soybean']
n_class = len(classes)
samples_per_class = 4

# Plot 4 images of each class
for Y, cls in enumerate(classes):
  indexes = np.flatnonzero(Y == Y_train)
  indexes = np.random.choice(indexes, samples_per_class, replace=False)
  for i, index, in enumerate(indexes):
    plt_index = i * n_class + Y + 1
    plt.subplot(samples_per_class, n_class, plt_index)
    plt.imshow(X_train[index].reshape(image_width, image_height, image_channel).astype('uint8'))
    if i == 0: plt.title(cls)

plt.show()

# %%
class NeuralNetwork:
  hidden_size = 200
  input_size = image_width * image_height * image_channel
  output_size = n_class

  """
  w1: first layer weight
  w2: second layer weight
  """
  w1 = 1e-3 * np.random.randn(input_size, hidden_size)
  b1 = np.zeros(hidden_size)
  w2 = 1e-3 * np.random.randn(hidden_size, output_size)
  b2 = np.zeros(output_size)
    
  alpha = 1e-5
  batch_size = 100
    
  epochs = 500
  
  def train(self, X, Y, X_val, Y_val):
    N, D = X.shape
    N_val = X_val.shape[0]
    iteration_per_epoch = max(N / self.batch_size, 1)

    loss_hist = []
    train_acc_hist = []
    val_acc_hist = []
    
    for it in range(self.epochs):
      sampling = np.random.choice(np.arange(N), self.batch_size, replace=False) # Create random array data

      # Getting batches for x and y
      X_batch = X[sampling]
      Y_batch = Y[sampling]

      loss, grads = self.loss(X_batch, Y=Y_batch)
      loss_hist.append(loss)

      # Make the model learning and reshape the parameters of the network
      self.w1 += -1.0 * self.alpha * grads['w1']
      self.b1 += -1.0 * self.alpha * grads['b1']
      self.w2 += -1.0 * self.alpha * grads['w2']
      self.b2 += -1.0 * self.alpha * grads['b2']

      if it % 10 == 0:
        print('iteration: %d / %d | Loss: %f' % (it, self.epochs, loss))
    
      if it % iteration_per_epoch == 0:
        train_acc = (self.predict(X_batch) == Y_batch).mean()
        val_acc = (self.predict(X_val) == Y_val).mean()
        train_acc_hist.append(train_acc)
        val_acc_hist.append(val_acc)

        self.alpha *= 0.95
    
    return {
        'loss_hist': loss_hist,
        'train_acc_hist': train_acc_hist,
        'val_acc_hist': val_acc_hist
    }

  def relu(self, z):
    return np.maximum(0, z)
  
  def predict(self, X):
    Y_pred = None
    layer1 = self.relu(X.dot(self.w1) + self.b1)
    scores = layer1.dot(self.w2) + self.b2
    Y_pred = np.argmax(scores, axis=1)
    return Y_pred

  def loss(self, X, Y = None):
    N, D = X.shape

    # Calculate the loss of our layer1
    layer1 = self.relu(X.dot(self.w1) + self.b1)
    scores = layer1.dot(self.w2) + self.b2

    if (Y is None):
      return scores

    # Calculate the actual loss
    scores -= scores.max()
    scores = np.exp(scores)
    scores_sumexp = np.sum(scores, axis=1)
    softmax = scores / scores_sumexp.reshape(N, 1)
    loss = -1.0 * np.sum(np.log(softmax[range(N), Y]))
    loss /= N

    grads = {}
    correct_class_scores = scores[range(N), Y]
    softmax[range(N), Y] = -1.0 * (scores_sumexp - correct_class_scores) / scores_sumexp
    softmax /= N

    grads['w2'] = layer1.T.dot(softmax)
    grads['b2'] = np.sum(softmax, axis=0)

    hidden = softmax.dot(self.w2.T)

    grads['w1'] = X.T.dot(hidden)
    grads['b1'] = np.sum(hidden, axis=0)

    return loss, grads

# %%
nn = NeuralNetwork()
stats = nn.train(X_dev, Y_dev, X_val, Y_val)
# Out:
# iteration: 0 / 500 | Loss: 1.411318
# iteration: 10 / 500 | Loss: 1.343742
# iteration: 20 / 500 | Loss: 1.297852
# iteration: 30 / 500 | Loss: 1.261228
# iteration: 40 / 500 | Loss: 1.213070
# iteration: 50 / 500 | Loss: 1.190852
# iteration: 60 / 500 | Loss: 1.154435
# iteration: 70 / 500 | Loss: 1.127569
# iteration: 80 / 500 | Loss: 1.122248
# iteration: 90 / 500 | Loss: 1.109718
# iteration: 100 / 500 | Loss: 1.057801
# iteration: 110 / 500 | Loss: 1.074666
# iteration: 120 / 500 | Loss: 1.078584
# iteration: 130 / 500 | Loss: 1.015907
# iteration: 140 / 500 | Loss: 1.041080
# iteration: 150 / 500 | Loss: 1.060719
# iteration: 160 / 500 | Loss: 1.051826
# iteration: 170 / 500 | Loss: 1.025659
# iteration: 180 / 500 | Loss: 1.005496
# iteration: 190 / 500 | Loss: 1.038422
# iteration: 200 / 500 | Loss: 0.985968
# iteration: 210 / 500 | Loss: 1.000241
# iteration: 220 / 500 | Loss: 0.989243
# iteration: 230 / 500 | Loss: 1.004149
# iteration: 240 / 500 | Loss: 0.973005
# iteration: 250 / 500 | Loss: 1.056347
# iteration: 260 / 500 | Loss: 0.988271
# iteration: 270 / 500 | Loss: 1.010076
# iteration: 280 / 500 | Loss: 0.974429
# iteration: 290 / 500 | Loss: 0.890798
# iteration: 300 / 500 | Loss: 0.938112
# iteration: 310 / 500 | Loss: 1.029931
# iteration: 320 / 500 | Loss: 0.949054
# iteration: 330 / 500 | Loss: 0.987356
# iteration: 340 / 500 | Loss: 0.951227
# iteration: 350 / 500 | Loss: 0.941446
# iteration: 360 / 500 | Loss: 0.951029
# iteration: 370 / 500 | Loss: 0.954193
# iteration: 380 / 500 | Loss: 0.980591
# iteration: 390 / 500 | Loss: 0.904746
# iteration: 400 / 500 | Loss: 0.989290
# iteration: 410 / 500 | Loss: 1.031142
# iteration: 420 / 500 | Loss: 0.926070
# iteration: 430 / 500 | Loss: 0.982424
# iteration: 440 / 500 | Loss: 0.959170
# iteration: 450 / 500 | Loss: 0.963128
# iteration: 460 / 500 | Loss: 0.978733
# iteration: 470 / 500 | Loss: 0.932711
# iteration: 480 / 500 | Loss: 1.011284
# iteration: 490 / 500 | Loss: 0.998799

# %%
print((nn.predict(X_test) == Y_test).mean())
# Out:
# 0.675

# %%
index = np.flatnonzero(0 == Y_train)
index = np.random.choice(index, 1, replace=False)
prediction = nn.predict(X_train[index])

plt.subplot(1, 2, 1)
plt.title('{} | {}'.format(classes[0], classes[prediction[0]]))
plt.imshow(X_train[index].reshape(image_width, image_height, image_channel).astype('uint8'))

index = np.flatnonzero(1 == Y_train)
index = np.random.choice(index, 1, replace=False)
prediction = nn.predict(X_train[index])

plt.subplot(1, 2, 2)
plt.title('{} | {}'.format(classes[1], classes[prediction[0]]))
plt.imshow(X_train[index].reshape(image_width, image_height, image_channel).astype('uint8'))
